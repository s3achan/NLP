# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                                              Question  \
# 0   What is a necessary set of skills and knowledg...
# 1   What is a characteristic function that data sc...
# 2   What percentage of global companies are using ...
# 3   In what field(s) do data scientists commonly w...
# 4         What is a good source of portfolio content?
# 5   What is a good way to decide which skills to h...
# 6   If you decide to build a new project to includ...
# 7   Should you include hobbies and interests on yo...
# 8    What is usually the largest part of your resume?
# 9   Why should you pay attention to the language u...
# 10  Why should you check social media to find out ...
# 11  Which three of the following are effective net...
# 12  What percentage of recruiters use LinkedIn as ...
# 13  Which of the following is true about working a...
# 14  What is a red flag that might indicate thinkin...
# 15  Which two statements are true about qualificat...
# ...
